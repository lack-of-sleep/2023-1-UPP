# %% [markdown]
# <a href="https://colab.research.google.com/github/lack-of-sleep/2023-1-UPP/blob/main/coling_hw01__1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#01
import nltk
nltk.download("book", quiet=True)
# Out:
# True

# %%
#02
from nltk.book import *

# %%
#03
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
sent5
# Out:
# ['I',
#  'have',
#  'a',
#  'problem',
#  'with',
#  'people',
#  'PMing',
#  'me',
#  'to',
#  'lol',
#  'JOIN']

# %%
sent9
# Out:
# ['THE',
#  'suburb',
#  'of',
#  'Saffron',
#  'Park',
#  'lay',
#  'on',
#  'the',
#  'sunset',
#  'side',
#  'of',
#  'London',
#  ',',
#  'as',
#  'red',
#  'and',
#  'ragged',
#  'as',
#  'a',
#  'cloud',
#  'of',
#  'sunset',
#  '.']

# %%
text9
# Out:
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>

# %%
sent10 = ['I', 'love', 'you']
sent10
# Out:
# ['I', 'love', 'you']

# %%
print("sent10:", " ".join(sent10))
print("sent10:", " ^^* " .join(sent10))
# Out:
# sent10: I love you
# sent10: I ^^* love ^^* you

# %%
#04
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
#05
text1.concordance("mean")
# Out:
# Displaying 25 of 40 matches:
# ver conscious of my lungs , I do not mean to have it inferred that I ever go t
# at indignity amount to , weighed , I mean , in the scales of the New Testament
# " Broke ," said I --" BROKE , do you mean ?" " Sartain , and that ' s the very
# ith a madman ; and you , sir , YOU I mean , landlord , YOU , sir , by trying t
# hly complexion , that part of it , I mean , lying round about , and completely
# mpare with a country - bred one -- I mean a downright bumpkin dandy -- a fello
#  Queequeg , " what in thunder do you mean by that ? Don ' t you know you might
# per ? a cold clam ; is THAT what you mean , Mrs . Hussey ?" says I , " but tha
# he has only one leg ." " What do you mean , sir ? Was the other one lost by a
# roduced their papers . " What do you mean by that , Captain Peleg ?" said I ,
#  comrade standing on the wharf . " I mean ," he replied , " he must show his p
# ...

# %%
#06
text1.concordance("affection")
# Out:
# Displaying 3 of 3 matches:
# oyously assented ; for besides the affection I now felt for Queequeg , he was a
# e enough , yet he had a particular affection for his own harpoon , because it w
# ing cobbling jobs . Lord ! what an affection all old women have for tinkers . I

# %%
#07
text2.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# . " Now , Palmer , you shall see a monstrous pretty girl ." He immediately went
# your sister is to marry him . I am monstrous glad of it , for then I shall have
# ou may tell your sister . She is a monstrous lucky girl to get him , upon my ho
# k how you will like them . Lucy is monstrous pretty , and so good humoured and
#  Jennings , " I am sure I shall be monstrous glad of Miss Marianne ' s company
#  usual noisy cheerfulness , " I am monstrous glad to see you -- sorry I could n
# t however , as it turns out , I am monstrous glad there was never any thing in
# so scornfully ! for they say he is monstrous fond of her , as well he may . I s
# possible that she should ." " I am monstrous glad of it . Good gracious ! I hav
# thing of the kind . So then he was monstrous happy , and talked on some time ab
# e very genteel people . He makes a monstrous deal of money , and they keep thei

# %%
#08
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
#09
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
#10
text2.common_contexts(["monstrous", "very"])
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %%
#11
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %%
#12
import numpy
import matplotlib

# %%
#13
text3.generate()
# Out:
# laid by her , and said unto Cain , Where art thou , and said , Go to ,
# I will not do it for ten ' s sons ; we dreamed each man according to
# their generatio the firstborn said unto Laban , Because I said , Nay ,
# but Sarah shall her name be . , duke Elah , duke Shobal , and Akan .
# and looked upon my affliction . Bashemath Ishmael ' s blood , but Isra
# for as a prince hast thou found of all the cattle in the valley , and
# the wo The
# "laid by her , and said unto Cain , Where art thou , and said , Go to ,\nI will not do it for ten ' s sons ; we dreamed each man according to\ntheir generatio the firstborn said unto Laban , Because I said , Nay ,\nbut Sarah shall her name be . , duke Elah , duke Shobal , and Akan .\nand looked upon my affliction . Bashemath Ishmael ' s blood , but Isra\nfor as a prince hast thou found of all the cattle in the valley , and\nthe wo The"

# %%
#14
len(text3)
# Out:
# 44764

# %%
len(text9)
# Out:
# 69213

# %%
#15
set(text3)
# Out:
# {'rebuked',
#  'castles',
#  'Levi',
#  'grisl',
#  'Jebusites',
#  'ear',
#  'of',
#  'strengthened',
#  'true',
#  'afar',
#  'month',
#  'silver',
#  'fail',
#  'many',
#  'Pau',
#  'sore',
#  'them',
#  'host',
#  'journeyed',
#  'ey',
#  'olive',
#  'vessels',
#  'hearts',
#  'person',
#  'Massa',
#  'grapes',
#  'former',
#  'e',
#  'plagued',
#  'Reub',
#  'almon',
#  'spices',
#  'parts',
#  'halted',
#  'Assyria',
#  'Gether',
#  'quickly',
#  'Appoint',
#  'sixth',
#  'concerning',
#  'worshipped',
#  'instead',
#  'bad',
#  'serpent',
#  'land',
#  'sawest',
#  'afterwards',
#  'Methusa',
#  'pris',
#  'Shaveh',
#  'deceitfully',
#  'flo',
#  'played',
#  'business',
#  'strong',
#  'Beor',
#  'fly',
#  'lovest',
#  'years',
#  'nakedness',
#  'Heth',
#  'possessi',
#  'stooped',
#  'Mehujael',
#  'eaten',
#  'emptied',
#  'reason',
#  'strength',
#  'rose',
#  'certainly',
#  'repented',
#  'into',
#  'stolen',
#  'themselves',
#  'long',
#  'Lay',
#  'The',
#  'herb',
# ...

# %%
sorted(text3)
# Out:
# ['!',
#  '!',
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
#  "'",
# ...

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
#16
text3
# Out:
# <Text: The Book of Genesis>

# %%
len(text3)
# Out:
# 44764

# %%
len(text3)-len(set(text3))
# Out:
# 41975

# %%
#17
from __future__ import division

# %%
len(text3) / len(set(text3))
# Out:
# 16.050197203298673

# %%
len(set(text3)) / len(text3)
# Out:
# 0.06230453042623537

# %%
#18
text3.count("smote")
# Out:
# 5

# %%
text1.count("the")
# Out:
# 13721

# %%
text1.count("pretty")
# Out:
# 28

# %%
text4.count('a')/len(text4)
# Out:
# 0.01457806031353621

# %%
100*text4.count('a')/len(text4)
# Out:
# 1.457806031353621

# %%
#19~20
def lexical_diversity(text):
  return len(set(text))/len(text)

# %%
#21
def percentage(count, total):
  return 100*count/total

# %%
#22
lexical_diversity(text3)
# Out:
# 0.06230453042623537

# %%
lexical_diversity(text5)
# Out:
# 0.13477005109975562

# %%
#23
percentage(4, 5)
# Out:
# 80.0

# %%
percentage(text4.count('a'), len(text4))
# Out:
# 1.457806031353621

# %%
#24
from nltk.book import *

# %%
#25
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
def lexical_diversity(text):
  return len(set(text))/len(text)

# %%
lexical_diversity(sent1)
# Out:
# 1.0

# %%
#26
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
sent9
# Out:
# ['THE',
#  'suburb',
#  'of',
#  'Saffron',
#  'Park',
#  'lay',
#  'on',
#  'the',
#  'sunset',
#  'side',
#  'of',
#  'London',
#  ',',
#  'as',
#  'red',
#  'and',
#  'ragged',
#  'as',
#  'a',
#  'cloud',
#  'of',
#  'sunset',
#  '.']

# %%
#27
sent1 = ['Call', 'me', 'Ishmael', '.']

# %%
#28
['Monty', 'Python'] + ['and', 'the', 'Holy', 'Grail']
# Out:
# ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']

# %%
#29
sent1 + sent2
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
ex1 = ['철수는','영희를','사랑한다','.']

# %%
sent9 + ex1
# Out:
# ['THE',
#  'suburb',
#  'of',
#  'Saffron',
#  'Park',
#  'lay',
#  'on',
#  'the',
#  'sunset',
#  'side',
#  'of',
#  'London',
#  ',',
#  'as',
#  'red',
#  'and',
#  'ragged',
#  'as',
#  'a',
#  'cloud',
#  'of',
#  'sunset',
#  '.',
#  '철수는',
#  '영희를',
#  '사랑한다',
#  '.']

# %%
#30
sent1.append("Some")

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Some']

# %%
#31
sent100 = sent3 +ex1

# %%
sent100
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.',
#  '철수는',
#  '영희를',
#  '사랑한다',
#  '.']

# %%
sent100.append("정말로")

# %%
sent100
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.',
#  '철수는',
#  '영희를',
#  '사랑한다',
#  '.',
#  '정말로']

# %%
#32
text4[173]
# Out:
# 'awaken'

# %%
text9[173]
# Out:
# 'and'

# %%
text4[0]
# Out:
# 'Fellow'

# %%
#33
text4.index('awaken')
# Out:
# 173

# %%
text9.index('and')
# Out:
# 27

# %%
#34
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Some']

# %%
#35
sent = ['word1', 'word2', 'word3', 'word4', 'word5','word6', 'word7', 'word8', 'word9', 'word10']

# %%
sent[0]
# Out:
# 'word1'

# %%
sent[9]
# Out:
# 'word10'

# %%
#36
text5[16715:16735]
# Out:
# ['U86',
#  'thats',
#  'why',
#  'something',
#  'like',
#  'gamefly',
#  'is',
#  'so',
#  'good',
#  'because',
#  'you',
#  'can',
#  'actually',
#  'play',
#  'a',
#  'full',
#  'game',
#  'without',
#  'buying',
#  'it']

# %%
text6[1600:1625]
# Out:
# ['We',
#  "'",
#  're',
#  'an',
#  'anarcho',
#  '-',
#  'syndicalist',
#  'commune',
#  '.',
#  'We',
#  'take',
#  'it',
#  'in',
#  'turns',
#  'to',
#  'act',
#  'as',
#  'a',
#  'sort',
#  'of',
#  'executive',
#  'officer',
#  'for',
#  'the',
#  'week']

# %%
#37
sent[8]
# Out:
# 'word9'

# %%
sent[9]
# Out:
# 'word10'

# %%
#38
sent[5:8]
# Out:
# ['word6', 'word7', 'word8']

# %%
sent[5]
# Out:
# 'word6'

# %%
sent[6]
# Out:
# 'word7'

# %%
sent[7]
# Out:
# 'word8'

# %%
#39
sent[:3]
# Out:
# ['word1', 'word2', 'word3']

# %%
sent[4:]
# Out:
# ['word5', 'word6', 'word7', 'word8', 'word9', 'word10']

# %%
text2[141525:]
# Out:
# ['among',
#  'the',
#  'merits',
#  'and',
#  'the',
#  'happiness',
#  'of',
#  'Elinor',
#  'and',
#  'Marianne',
#  ',',
#  'let',
#  'it',
#  'not',
#  'be',
#  'ranked',
#  'as',
#  'the',
#  'least',
#  'considerable',
#  ',',
#  'that',
#  'though',
#  'sisters',
#  ',',
#  'and',
#  'living',
#  'almost',
#  'within',
#  'sight',
#  'of',
#  'each',
#  'other',
#  ',',
#  'they',
#  'could',
#  'live',
#  'without',
#  'disagreement',
#  'between',
#  'themselves',
#  ',',
#  'or',
#  'producing',
#  'coolness',
#  'between',
#  'their',
#  'husbands',
#  '.',
#  'THE',
#  'END']

# %%
#40
sent[0] = 'First'
sent[9] = 'Last'

# %%
len(sent)
# Out:
# 10

# %%
sent
# Out:
# ['First',
#  'word2',
#  'word3',
#  'word4',
#  'word5',
#  'word6',
#  'word7',
#  'word8',
#  'word9',
#  'Last']

# %%
#41
sent[1:9] = ['Second', 'Third']
sent
# Out:
# ['First', 'Second', 'Third', 'Last']

# %%
#42
sent1 = ['Call', 'me', 'Ishmael', '.']

# %%
#43
my_sent = ['Bravely', 'bold', 'Sir', 'Robin', ',', 'rode','forth', 'from', 'Camelot', '.']

# %%
noun_phrase = my_sent[1:4]
noun_phrase
# Out:
# ['bold', 'Sir', 'Robin']

# %%
wOrDs = sorted(noun_phrase)
wOrDs
# Out:
# ['Robin', 'Sir', 'bold']

# %%
#44
not = 'Camelot'
# Out:
#   File "<ipython-input-246-3643d2b7a2be>", line 2
#     not = 'Camelot'
#         ^
# SyntaxError: invalid syntax

# %%
#45
len(set(text1))
# Out:
# 19317

# %%
#46
vocab = set(text1)
vocab_size = len(vocab)
vocab_size
# Out:
# 19317

# %%
#47
name = 'Monty'
name[0]
# Out:
# 'M'

# %%
name[:4]
# Out:
# 'Mont'

# %%
name2 = '대전'
name2[1]
# Out:
# '전'

# %%
#48
name*2
# Out:
# 'MontyMonty'

# %%
name+'!'
# Out:
# 'Monty!'

# %%
name2*3
# Out:
# '대전대전대전'

# %%
name2+'충남대학교'
# Out:
# '대전충남대학교'

# %%
name2+'충남대학교 언어학과'
# Out:
# '대전충남대학교 언어학과'

# %%
name2+' 충남대학교 언어학과'
# Out:
# '대전 충남대학교 언어학과'

# %%
#49
' '.join(['Monty','Python'])
# Out:
# 'Monty Python'

# %%
name2.join(['충남대학교', '언어학과'])
# Out:
# '충남대학교대전언어학과'

# %%
name2.join([' 충남대학교', ' 언어학과'])
# Out:
# ' 충남대학교대전 언어학과'

# %%
name2.join([' 충남대학교', ' 언어학과','전산언어학'])
# Out:
# ' 충남대학교대전 언어학과대전전산언어학'

# %%
name2.join([' 충남대학교', ' 언어학과',' 전산언어학'])
# Out:
# ' 충남대학교대전 언어학과대전 전산언어학'

# %%
name2.join([' 충남대학교', ' 언어학과',' 전산언어학',' 류병래'])
# Out:
# ' 충남대학교대전 언어학과대전 전산언어학대전 류병래'

# %%
#50
'Monty Python'.split()
# Out:
# ['Monty', 'Python']

# %%
#51
name3 = name2.join([' 충남대학교', ' 언어학과',' 전산언어학',' 류병래'])
name3
# Out:
# ' 충남대학교대전 언어학과대전 전산언어학대전 류병래'

# %%
split(name3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-266-547b205e1a60> in <cell line: 1>()
# ----> 1 split(name3)
#
# NameError: name 'split' is not defined

# %%
name3.split()
